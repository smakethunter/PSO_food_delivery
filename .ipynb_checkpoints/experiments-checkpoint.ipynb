# %%
import matplotlib.pyplot as plt
import pandas as pd
from PSO import *
from delivery_swarm import *
from IPython.display import Image
from summary import *

# %matplotlib inline

# %% [markdown]
# ## Utworzenie przypadku i zapis do pliku

# %% [markdown]
# Definicja parametrów:

# %%
nr_couriers = 4
nr_orders = 11
nr_restaurants = 2

# %% [markdown]
# Zapis przypadku testowego do pliku:

# %%
case_nr = len(pd.read_csv('summary.csv'))

particle = DeliveryService(nr_couriers, nr_orders, nr_restaurants)
filename = 'Case' + str(case_nr) + '_' + str(nr_couriers) +'couriers_' + str(nr_orders) + 'orders_' + str(nr_restaurants) + 'restaurants.txt'
particle.save_to_file('./cases/' + filename)
del particle
filename
# Out:
# 'Case219_4couriers_11orders_2restaurants.txt'

# %% [markdown]
# ## Odtworzenie roju z pliku i eksperyment
# Wykonaj eksperymenty dla różnych parametrów {inertia,cp,cg}

# %% [markdown]
# Wybór parametrów:

# %%
inertia = 0.1
cp = 0.2
cg = 0.3

nr_particles = 20
nr_epochs = 30

# %% [markdown]
# Wywołanie algorytmu:

# %%
run_pso_and_save_summary(filename, nr_particles, inertia, cp, cg, nr_epochs)

# %% [markdown]
# Odczyt rezultatów z pliku:

# %%
experiments_logs = pd.read_csv('summary.csv')

# %%
experiments_logs[experiments_logs["case_name"] == filename.split('.')[0]]
# Out:
#                                    case_name  PSO_time  avg_v_computation  \
# 219  Case219_4couriers_11orders_2restaurants  1.821589           0.001993
#
#      avg_move_time  avg_epoch_time  avg_fitness_calculation_time       loss  \
# 219       0.000217        0.060421                      0.000292  31.250968
#
#      nr_changes  nr_orders  nr_restaurants  ...  nr_particles  nr_epochs  \
# 219           6         11               2  ...            20         30
#
#      inertia   cp   cg                             particles_history_plot  \
# 219      0.1  0.2  0.3  swarm_loss_plots/Case219_4couriers_11orders_2r...
#
#                                      loss_history_plot  \
# 219  loss_history_plots/Case219_4couriers_11orders_...
#
#                                         best_path_plot  \
# 219  best_path_plots/Case219_4couriers_11orders_2re...
#
#                                 changes_per_epoch_plot  \
# 219  changes_per_epoch_plots/Case219_4couriers_11or...
#
#                               experiment_documentation
# 219  experiments_documentation/Case219_4couriers_11...
#
# [1 rows x 21 columns]

# %%
Image(experiments_logs['changes_per_epoch_plot'][case_nr])

# %%
Image(experiments_logs['loss_history_plot'][case_nr])

# %%
Image(experiments_logs['particles_history_plot'][case_nr])

# %%
Image(experiments_logs['best_path_plot'][case_nr])

# %% [markdown]
# ## Działanie algorytmu dla zmieniającej się liczby cząstek

# %% [markdown]
# Parametry:

# %%
import matplotlib.pyplot as plt
import pandas as pd
from PSO import *
from delivery_swarm import *
from IPython.display import Image
from summary import *

# %matplotlib inline

# %%
nr_couriers = 4
nr_orders = 11
nr_restaurants = 2

# %%
case_nr = len(pd.read_csv('summary.csv'))

particle = DeliveryService(nr_couriers, nr_orders, nr_restaurants)
filename = 'Case' + str(case_nr) + '_' + str(nr_couriers) +'couriers_' + str(nr_orders) + 'orders_' + str(nr_restaurants) + 'restaurants.txt'
particle.save_to_file('./cases/' + filename)
del particle
filename
# Out:
# 'Case220_4couriers_11orders_2restaurants.txt'

# %%
inertia = 0.1
cp = 0.2
cg = 0.3

nr_particles = range(21,40)
nr_epochs = 30

# %% [markdown]
# Działanie algorytmu:

# %%
for nr_particles in nr_particles:
    run_pso_and_save_summary(filename, nr_particles, inertia, cp, cg, nr_epochs)

# %%
experiments_logs = pd.read_csv('summary.csv')

# %%
particle_number_test_log = experiments_logs[experiments_logs["case_name"] == filename.split('.')[0]]

# %%
particle_number_test_log
# Out:
#                                    case_name  PSO_time  avg_v_computation  \
# 220  Case220_4couriers_11orders_2restaurants  1.691246           0.001759
# 221  Case220_4couriers_11orders_2restaurants  1.796076           0.001705
# 222  Case220_4couriers_11orders_2restaurants  1.390143           0.001238
# 223  Case220_4couriers_11orders_2restaurants  1.629309           0.001461
# 224  Case220_4couriers_11orders_2restaurants  1.935172           0.001701
# 225  Case220_4couriers_11orders_2restaurants  1.779140           0.001507
# 226  Case220_4couriers_11orders_2restaurants  1.827726           0.001443
# 227  Case220_4couriers_11orders_2restaurants  1.871211           0.001433
# 228  Case220_4couriers_11orders_2restaurants  2.236928           0.001710
# 229  Case220_4couriers_11orders_2restaurants  2.587724           0.001934
# 230  Case220_4couriers_11orders_2restaurants  2.558657           0.001774
# 231  Case220_4couriers_11orders_2restaurants  3.752682           0.002516
# 232  Case220_4couriers_11orders_2restaurants  2.068156           0.001347
# 233  Case220_4couriers_11orders_2restaurants  2.680298           0.001757
# 234  Case220_4couriers_11orders_2restaurants  4.056310           0.002588
# 235  Case220_4couriers_11orders_2restaurants  2.993229           0.001837
# 236  Case220_4couriers_11orders_2restaurants  2.694343           0.001606
# 237  Case220_4couriers_11orders_2restaurants  2.886384           0.001642
# 238  Case220_4couriers_11orders_2restaurants  2.181672           0.001207
#
#      avg_move_time  avg_epoch_time  avg_fitness_calculation_time       loss  \
# 220       0.000174        0.056109                      0.000310  48.684543
# 221       0.000200        0.059603                      0.000315  45.038754
# 222       0.000148        0.046171                      0.000244  50.344791
# 223       0.000156        0.053977                      0.000251  48.922865
# 224       0.000156        0.064273                      0.000285  35.127125
# 225       0.000140        0.059205                      0.000248  38.585189
# 226       0.000139        0.060858                      0.000271  43.275788
# 227       0.000150        0.062174                      0.000280  42.735121
# 228       0.000187        0.074364                      0.000256  44.400868
# 229       0.000201        0.086058                      0.000266  39.158006
# 230       0.000188        0.085155                      0.000310  39.597252
# 231       0.000242        0.124690                      0.000484  38.074967
# 232       0.000152        0.068772                      0.000218  38.846928
# 233       0.000177        0.089077                      0.000250  30.484071
# 234       0.000280        0.134944                      0.000370  46.310952
# 235       0.000190        0.099474                      0.000293  43.337957
# 236       0.000170        0.089545                      0.000258  38.959787
# 237       0.000187        0.096046                      0.000294  38.959787
# 238       0.000130        0.072589                      0.000213  43.957159
#
#      nr_changes  nr_orders  nr_restaurants  ...  nr_particles  nr_epochs  \
# 220           8         11               2  ...            21         30
# 221           8         11               2  ...            22         30
# 222           7         11               2  ...            23         30
# 223          10         11               2  ...            24         30
# 224           7         11               2  ...            25         30
# 225           7         11               2  ...            26         30
# 226          11         11               2  ...            27         30
# 227          11         11               2  ...            28         30
# 228          12         11               2  ...            29         30
# 229           2         11               2  ...            30         30
# 230          13         11               2  ...            31         30
# 231          12         11               2  ...            32         30
# 232           7         11               2  ...            33         30
# 233          10         11               2  ...            34         30
# 234           8         11               2  ...            35         30
# 235           8         11               2  ...            36         30
# 236           9         11               2  ...            37         30
# 237           6         11               2  ...            38         30
# 238           5         11               2  ...            39         30
#
#      inertia   cp   cg                             particles_history_plot  \
# 220      0.1  0.2  0.3  swarm_loss_plots/Case220_4couriers_11orders_2r...
# 221      0.1  0.2  0.3  swarm_loss_plots/Case220_4couriers_11orders_2r...
# 222      0.1  0.2  0.3  swarm_loss_plots/Case220_4couriers_11orders_2r...
# 223      0.1  0.2  0.3  swarm_loss_plots/Case220_4couriers_11orders_2r...
# 224      0.1  0.2  0.3  swarm_loss_plots/Case220_4couriers_11orders_2r...
# 225      0.1  0.2  0.3  swarm_loss_plots/Case220_4couriers_11orders_2r...
# 226      0.1  0.2  0.3  swarm_loss_plots/Case220_4couriers_11orders_2r...
# 227      0.1  0.2  0.3  swarm_loss_plots/Case220_4couriers_11orders_2r...
# 228      0.1  0.2  0.3  swarm_loss_plots/Case220_4couriers_11orders_2r...
# 229      0.1  0.2  0.3  swarm_loss_plots/Case220_4couriers_11orders_2r...
# 230      0.1  0.2  0.3  swarm_loss_plots/Case220_4couriers_11orders_2r...
# 231      0.1  0.2  0.3  swarm_loss_plots/Case220_4couriers_11orders_2r...
# 232      0.1  0.2  0.3  swarm_loss_plots/Case220_4couriers_11orders_2r...
# 233      0.1  0.2  0.3  swarm_loss_plots/Case220_4couriers_11orders_2r...
# 234      0.1  0.2  0.3  swarm_loss_plots/Case220_4couriers_11orders_2r...
# 235      0.1  0.2  0.3  swarm_loss_plots/Case220_4couriers_11orders_2r...
# 236      0.1  0.2  0.3  swarm_loss_plots/Case220_4couriers_11orders_2r...
# 237      0.1  0.2  0.3  swarm_loss_plots/Case220_4couriers_11orders_2r...
# 238      0.1  0.2  0.3  swarm_loss_plots/Case220_4couriers_11orders_2r...
#
#                                      loss_history_plot  \
# 220  loss_history_plots/Case220_4couriers_11orders_...
# 221  loss_history_plots/Case220_4couriers_11orders_...
# 222  loss_history_plots/Case220_4couriers_11orders_...
# 223  loss_history_plots/Case220_4couriers_11orders_...
# 224  loss_history_plots/Case220_4couriers_11orders_...
# 225  loss_history_plots/Case220_4couriers_11orders_...
# 226  loss_history_plots/Case220_4couriers_11orders_...
# 227  loss_history_plots/Case220_4couriers_11orders_...
# 228  loss_history_plots/Case220_4couriers_11orders_...
# 229  loss_history_plots/Case220_4couriers_11orders_...
# 230  loss_history_plots/Case220_4couriers_11orders_...
# 231  loss_history_plots/Case220_4couriers_11orders_...
# 232  loss_history_plots/Case220_4couriers_11orders_...
# 233  loss_history_plots/Case220_4couriers_11orders_...
# 234  loss_history_plots/Case220_4couriers_11orders_...
# 235  loss_history_plots/Case220_4couriers_11orders_...
# 236  loss_history_plots/Case220_4couriers_11orders_...
# 237  loss_history_plots/Case220_4couriers_11orders_...
# 238  loss_history_plots/Case220_4couriers_11orders_...
#
#                                         best_path_plot  \
# 220  best_path_plots/Case220_4couriers_11orders_2re...
# 221  best_path_plots/Case220_4couriers_11orders_2re...
# 222  best_path_plots/Case220_4couriers_11orders_2re...
# 223  best_path_plots/Case220_4couriers_11orders_2re...
# 224  best_path_plots/Case220_4couriers_11orders_2re...
# 225  best_path_plots/Case220_4couriers_11orders_2re...
# 226  best_path_plots/Case220_4couriers_11orders_2re...
# 227  best_path_plots/Case220_4couriers_11orders_2re...
# 228  best_path_plots/Case220_4couriers_11orders_2re...
# 229  best_path_plots/Case220_4couriers_11orders_2re...
# 230  best_path_plots/Case220_4couriers_11orders_2re...
# 231  best_path_plots/Case220_4couriers_11orders_2re...
# 232  best_path_plots/Case220_4couriers_11orders_2re...
# 233  best_path_plots/Case220_4couriers_11orders_2re...
# 234  best_path_plots/Case220_4couriers_11orders_2re...
# 235  best_path_plots/Case220_4couriers_11orders_2re...
# 236  best_path_plots/Case220_4couriers_11orders_2re...
# 237  best_path_plots/Case220_4couriers_11orders_2re...
# 238  best_path_plots/Case220_4couriers_11orders_2re...
#
#                                 changes_per_epoch_plot  \
# 220  changes_per_epoch_plots/Case220_4couriers_11or...
# 221  changes_per_epoch_plots/Case220_4couriers_11or...
# 222  changes_per_epoch_plots/Case220_4couriers_11or...
# 223  changes_per_epoch_plots/Case220_4couriers_11or...
# 224  changes_per_epoch_plots/Case220_4couriers_11or...
# 225  changes_per_epoch_plots/Case220_4couriers_11or...
# 226  changes_per_epoch_plots/Case220_4couriers_11or...
# 227  changes_per_epoch_plots/Case220_4couriers_11or...
# 228  changes_per_epoch_plots/Case220_4couriers_11or...
# 229  changes_per_epoch_plots/Case220_4couriers_11or...
# 230  changes_per_epoch_plots/Case220_4couriers_11or...
# 231  changes_per_epoch_plots/Case220_4couriers_11or...
# 232  changes_per_epoch_plots/Case220_4couriers_11or...
# 233  changes_per_epoch_plots/Case220_4couriers_11or...
# 234  changes_per_epoch_plots/Case220_4couriers_11or...
# 235  changes_per_epoch_plots/Case220_4couriers_11or...
# 236  changes_per_epoch_plots/Case220_4couriers_11or...
# 237  changes_per_epoch_plots/Case220_4couriers_11or...
# 238  changes_per_epoch_plots/Case220_4couriers_11or...
#
#                               experiment_documentation
# 220  experiments_documentation/Case220_4couriers_11...
# 221  experiments_documentation/Case220_4couriers_11...
# 222  experiments_documentation/Case220_4couriers_11...
# 223  experiments_documentation/Case220_4couriers_11...
# 224  experiments_documentation/Case220_4couriers_11...
# 225  experiments_documentation/Case220_4couriers_11...
# 226  experiments_documentation/Case220_4couriers_11...
# 227  experiments_documentation/Case220_4couriers_11...
# 228  experiments_documentation/Case220_4couriers_11...
# 229  experiments_documentation/Case220_4couriers_11...
# 230  experiments_documentation/Case220_4couriers_11...
# 231  experiments_documentation/Case220_4couriers_11...
# 232  experiments_documentation/Case220_4couriers_11...
# 233  experiments_documentation/Case220_4couriers_11...
# 234  experiments_documentation/Case220_4couriers_11...
# 235  experiments_documentation/Case220_4couriers_11...
# 236  experiments_documentation/Case220_4couriers_11...
# 237  experiments_documentation/Case220_4couriers_11...
# 238  experiments_documentation/Case220_4couriers_11...
#
# [19 rows x 21 columns]

# %%
particle_number_test_log.plot.bar(x='nr_particles',y='loss', title='Błąd w zależności od liczby osobników', figsize=(12,8))

# %%
particle_number_test_log.plot.bar(x='nr_particles', y='PSO_time', title='Czas działania algorytmu w zależności od liczby osobników', figsize=(12,8))

# %%
particle_number_test_log.plot.bar(x='nr_particles', y='avg_epoch_time', title='Średni czas na epokę w zależności od liczby osobników', figsize=(12,8))

# %% [markdown]
# ## Działanie algorytmu przy zmieniającej się liczbie epok

# %% [markdown]
# Wybór parametrów i utworzenie przypadku:

# %%
import matplotlib.pyplot as plt
import pandas as pd
from PSO import *
from delivery_swarm import *
from IPython.display import Image
from summary import *

# %matplotlib inline

# %%
nr_couriers = 4
nr_orders = 11
nr_restaurants = 2

# %%
case_nr = len(pd.read_csv('summary.csv'))

particle = DeliveryService(nr_couriers, nr_orders, nr_restaurants)
filename = 'Case' + str(case_nr) + '_' + str(nr_couriers) +'couriers_' + str(nr_orders) + 'orders_' + str(nr_restaurants) + 'restaurants.txt'
particle.save_to_file('./cases/' + filename)
del particle
filename
# Out:
# 'Case239_4couriers_11orders_2restaurants.txt'

# %%
inertia = 0.1
cp = 0.2
cg = 0.3

nr_particles = 30
nr_epochs = range(20, 40)

# %% [markdown]
# Działanie algorytmu:

# %%
for nr_epochs in nr_epochs:
    run_pso_and_save_summary(filename, nr_particles, inertia, cp, cg, nr_epochs)

# %%
experiments_logs = pd.read_csv('summary.csv')

# %%
particle_number_test_log = experiments_logs[experiments_logs["case_name"] == filename.split('.')[0]]
particle_number_test_log
# Out:
#                                    case_name  PSO_time  avg_v_computation  \
# 239  Case239_4couriers_11orders_2restaurants  1.008077           0.001005
# 240  Case239_4couriers_11orders_2restaurants  1.004073           0.000962
# 241  Case239_4couriers_11orders_2restaurants  1.186089           0.001099
# 242  Case239_4couriers_11orders_2restaurants  1.087081           0.000930
# 243  Case239_4couriers_11orders_2restaurants  1.320097           0.001129
# 244  Case239_4couriers_11orders_2restaurants  1.349099           0.001072
# 245  Case239_4couriers_11orders_2restaurants  1.603120           0.001223
# 246  Case239_4couriers_11orders_2restaurants  1.285096           0.000958
# 247  Case239_4couriers_11orders_2restaurants  1.328097           0.000986
# 248  Case239_4couriers_11orders_2restaurants  1.495114           0.001060
# 249  Case239_4couriers_11orders_2restaurants  1.600120           0.001047
# 250  Case239_4couriers_11orders_2restaurants  1.701123           0.001194
# 251  Case239_4couriers_11orders_2restaurants  1.941140           0.001252
# 252  Case239_4couriers_11orders_2restaurants  1.625120           0.001018
# 253  Case239_4couriers_11orders_2restaurants  1.598137           0.001009
# 254  Case239_4couriers_11orders_2restaurants  1.701126           0.000960
# 255  Case239_4couriers_11orders_2restaurants  1.638121           0.000902
# 256  Case239_4couriers_11orders_2restaurants  1.774132           0.000974
# 257  Case239_4couriers_11orders_2restaurants  2.571193           0.001498
# 258  Case239_4couriers_11orders_2restaurants  2.183164           0.001099
#
#      avg_move_time  avg_epoch_time  avg_fitness_calculation_time       loss  \
# 239       0.000098        0.050104                      0.000216  54.159127
# 240       0.000095        0.047623                      0.000232  55.050474
# 241       0.000095        0.053868                      0.000271  53.681848
# 242       0.000102        0.047090                      0.000214  61.963709
# 243       0.000120        0.054879                      0.000250  61.208980
# 244       0.000091        0.053684                      0.000284  58.050079
# 245       0.000123        0.061312                      0.000292  56.395021
# 246       0.000107        0.047374                      0.000200  55.300415
# 247       0.000105        0.047218                      0.000206  54.736975
# 248       0.000103        0.051349                      0.000216  59.089491
# 249       0.000103        0.053104                      0.000246  54.867869
# 250       0.000108        0.054649                      0.000228  52.650129
# 251       0.000167        0.060442                      0.000246  52.663495
# 252       0.000094        0.049155                      0.000234  63.506505
# 253       0.000106        0.046857                      0.000189  54.797639
# 254       0.000089        0.048461                      0.000225  61.254390
# 255       0.000115        0.045281                      0.000204  52.116401
# 256       0.000105        0.047841                      0.000212  50.895038
# 257       0.000154        0.067505                      0.000210  51.885394
# 258       0.000123        0.055825                      0.000255  72.067035
#
#      nr_changes  nr_orders  nr_restaurants  ...  nr_particles  nr_epochs  \
# 239           9         11               2  ...            30         20
# 240           9         11               2  ...            30         21
# 241           9         11               2  ...            30         22
# 242           9         11               2  ...            30         23
# 243          12         11               2  ...            30         24
# 244          10         11               2  ...            30         25
# 245          13         11               2  ...            30         26
# 246          16         11               2  ...            30         27
# 247          17         11               2  ...            30         28
# 248          14         11               2  ...            30         29
# 249          11         11               2  ...            30         30
# 250          12         11               2  ...            30         31
# 251          14         11               2  ...            30         32
# 252          13         11               2  ...            30         33
# 253          10         11               2  ...            30         34
# 254          11         11               2  ...            30         35
# 255          10         11               2  ...            30         36
# 256          13         11               2  ...            30         37
# 257          12         11               2  ...            30         38
# 258          11         11               2  ...            30         39
#
#      inertia   cp   cg                             particles_history_plot  \
# 239      0.1  0.2  0.3  swarm_loss_plots/Case239_4couriers_11orders_2r...
# 240      0.1  0.2  0.3  swarm_loss_plots/Case239_4couriers_11orders_2r...
# 241      0.1  0.2  0.3  swarm_loss_plots/Case239_4couriers_11orders_2r...
# 242      0.1  0.2  0.3  swarm_loss_plots/Case239_4couriers_11orders_2r...
# 243      0.1  0.2  0.3  swarm_loss_plots/Case239_4couriers_11orders_2r...
# 244      0.1  0.2  0.3  swarm_loss_plots/Case239_4couriers_11orders_2r...
# 245      0.1  0.2  0.3  swarm_loss_plots/Case239_4couriers_11orders_2r...
# 246      0.1  0.2  0.3  swarm_loss_plots/Case239_4couriers_11orders_2r...
# 247      0.1  0.2  0.3  swarm_loss_plots/Case239_4couriers_11orders_2r...
# 248      0.1  0.2  0.3  swarm_loss_plots/Case239_4couriers_11orders_2r...
# 249      0.1  0.2  0.3  swarm_loss_plots/Case239_4couriers_11orders_2r...
# 250      0.1  0.2  0.3  swarm_loss_plots/Case239_4couriers_11orders_2r...
# 251      0.1  0.2  0.3  swarm_loss_plots/Case239_4couriers_11orders_2r...
# 252      0.1  0.2  0.3  swarm_loss_plots/Case239_4couriers_11orders_2r...
# 253      0.1  0.2  0.3  swarm_loss_plots/Case239_4couriers_11orders_2r...
# 254      0.1  0.2  0.3  swarm_loss_plots/Case239_4couriers_11orders_2r...
# 255      0.1  0.2  0.3  swarm_loss_plots/Case239_4couriers_11orders_2r...
# 256      0.1  0.2  0.3  swarm_loss_plots/Case239_4couriers_11orders_2r...
# 257      0.1  0.2  0.3  swarm_loss_plots/Case239_4couriers_11orders_2r...
# 258      0.1  0.2  0.3  swarm_loss_plots/Case239_4couriers_11orders_2r...
#
#                                      loss_history_plot  \
# 239  loss_history_plots/Case239_4couriers_11orders_...
# 240  loss_history_plots/Case239_4couriers_11orders_...
# 241  loss_history_plots/Case239_4couriers_11orders_...
# 242  loss_history_plots/Case239_4couriers_11orders_...
# 243  loss_history_plots/Case239_4couriers_11orders_...
# 244  loss_history_plots/Case239_4couriers_11orders_...
# 245  loss_history_plots/Case239_4couriers_11orders_...
# 246  loss_history_plots/Case239_4couriers_11orders_...
# 247  loss_history_plots/Case239_4couriers_11orders_...
# 248  loss_history_plots/Case239_4couriers_11orders_...
# 249  loss_history_plots/Case239_4couriers_11orders_...
# 250  loss_history_plots/Case239_4couriers_11orders_...
# 251  loss_history_plots/Case239_4couriers_11orders_...
# 252  loss_history_plots/Case239_4couriers_11orders_...
# 253  loss_history_plots/Case239_4couriers_11orders_...
# 254  loss_history_plots/Case239_4couriers_11orders_...
# 255  loss_history_plots/Case239_4couriers_11orders_...
# 256  loss_history_plots/Case239_4couriers_11orders_...
# 257  loss_history_plots/Case239_4couriers_11orders_...
# 258  loss_history_plots/Case239_4couriers_11orders_...
#
#                                         best_path_plot  \
# 239  best_path_plots/Case239_4couriers_11orders_2re...
# 240  best_path_plots/Case239_4couriers_11orders_2re...
# 241  best_path_plots/Case239_4couriers_11orders_2re...
# 242  best_path_plots/Case239_4couriers_11orders_2re...
# 243  best_path_plots/Case239_4couriers_11orders_2re...
# 244  best_path_plots/Case239_4couriers_11orders_2re...
# 245  best_path_plots/Case239_4couriers_11orders_2re...
# 246  best_path_plots/Case239_4couriers_11orders_2re...
# 247  best_path_plots/Case239_4couriers_11orders_2re...
# 248  best_path_plots/Case239_4couriers_11orders_2re...
# 249  best_path_plots/Case239_4couriers_11orders_2re...
# 250  best_path_plots/Case239_4couriers_11orders_2re...
# 251  best_path_plots/Case239_4couriers_11orders_2re...
# 252  best_path_plots/Case239_4couriers_11orders_2re...
# 253  best_path_plots/Case239_4couriers_11orders_2re...
# 254  best_path_plots/Case239_4couriers_11orders_2re...
# 255  best_path_plots/Case239_4couriers_11orders_2re...
# 256  best_path_plots/Case239_4couriers_11orders_2re...
# 257  best_path_plots/Case239_4couriers_11orders_2re...
# 258  best_path_plots/Case239_4couriers_11orders_2re...
#
#                                 changes_per_epoch_plot  \
# 239  changes_per_epoch_plots/Case239_4couriers_11or...
# 240  changes_per_epoch_plots/Case239_4couriers_11or...
# 241  changes_per_epoch_plots/Case239_4couriers_11or...
# 242  changes_per_epoch_plots/Case239_4couriers_11or...
# 243  changes_per_epoch_plots/Case239_4couriers_11or...
# 244  changes_per_epoch_plots/Case239_4couriers_11or...
# 245  changes_per_epoch_plots/Case239_4couriers_11or...
# 246  changes_per_epoch_plots/Case239_4couriers_11or...
# 247  changes_per_epoch_plots/Case239_4couriers_11or...
# 248  changes_per_epoch_plots/Case239_4couriers_11or...
# 249  changes_per_epoch_plots/Case239_4couriers_11or...
# 250  changes_per_epoch_plots/Case239_4couriers_11or...
# 251  changes_per_epoch_plots/Case239_4couriers_11or...
# 252  changes_per_epoch_plots/Case239_4couriers_11or...
# 253  changes_per_epoch_plots/Case239_4couriers_11or...
# 254  changes_per_epoch_plots/Case239_4couriers_11or...
# 255  changes_per_epoch_plots/Case239_4couriers_11or...
# 256  changes_per_epoch_plots/Case239_4couriers_11or...
# 257  changes_per_epoch_plots/Case239_4couriers_11or...
# 258  changes_per_epoch_plots/Case239_4couriers_11or...
#
#                               experiment_documentation
# 239  experiments_documentation/Case239_4couriers_11...
# 240  experiments_documentation/Case239_4couriers_11...
# 241  experiments_documentation/Case239_4couriers_11...
# 242  experiments_documentation/Case239_4couriers_11...
# 243  experiments_documentation/Case239_4couriers_11...
# 244  experiments_documentation/Case239_4couriers_11...
# 245  experiments_documentation/Case239_4couriers_11...
# 246  experiments_documentation/Case239_4couriers_11...
# 247  experiments_documentation/Case239_4couriers_11...
# 248  experiments_documentation/Case239_4couriers_11...
# 249  experiments_documentation/Case239_4couriers_11...
# 250  experiments_documentation/Case239_4couriers_11...
# 251  experiments_documentation/Case239_4couriers_11...
# 252  experiments_documentation/Case239_4couriers_11...
# 253  experiments_documentation/Case239_4couriers_11...
# 254  experiments_documentation/Case239_4couriers_11...
# 255  experiments_documentation/Case239_4couriers_11...
# 256  experiments_documentation/Case239_4couriers_11...
# 257  experiments_documentation/Case239_4couriers_11...
# 258  experiments_documentation/Case239_4couriers_11...
#
# [20 rows x 21 columns]

# %%
particle_number_test_log.plot.bar(x='nr_particles',y='loss', title='Błąd w zależności od liczby osobników', figsize=(12,8))

# %%
particle_number_test_log.plot.bar(x='nr_particles', y='PSO_time', title='Czas działania algorytmu w zależności od liczby osobników', figsize=(12,8))

# %%
particle_number_test_log.plot.bar(x='nr_particles', y='avg_epoch_time', title='Średni czas na epokę w zależności od liczby osobników', figsize=(12,8))

# %% [markdown]
# ## Wnioski

# %% [markdown]
# Nie zauważono znaczących popraw wartości funkcji kosztu w zbadanym zakresie zmian ilości cząstek i epok.
