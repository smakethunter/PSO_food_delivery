# %%
import numpy as np

import matplotlib.pyplot as plt
from PSO import *
from delivery_swarm import *

# %matplotlib inline

# %% [markdown]
# ## Utworzenie przypadku i zapis do pliku
# 1. przed utworzeniem zrestartuj kernel
# 2. przy tworzeniu nowego przypadku zastosuj ./cases/NazwaPrzypadku(liczba_kurierów)k(liczba_zamówień)z(liczba_restauracji)r.txt

# %%
particle = DeliveryService(nr_couriers = 1, nr_orders = 1000, nr_restaurants = 10)
filename = './cases/przypadek1k1000z10r.txt'
particle.save_to_file(filename)
del particle
del filename
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-5-702f76371850> in <module>
# ----> 1 particle = DeliveryService(nr_couriers = 1, nr_orders = 1000, nr_restaurants = 10)
#       2 filename = './cases/przypadek1k1000z10r.txt'
#       3 particle.save_to_file(filename)
#       4 del particle
#       5 del filename
#
# ~/PycharmProjects/PSO_food_delivery/delivery_swarm.py in __init__(self, nr_couriers, nr_orders, nr_restaurants, from_file, filename)
#     179         super(DeliveryService, self).__init__()
#     180
# --> 181         starting_position = DeliveryServiceGenerator(nr_orders, nr_restaurants, nr_couriers, from_file=from_file, filename=filename)
#     182         self.nr_couriers = nr_couriers if nr_couriers is not None else starting_position.nr_rows
#     183         self.best_position: List[Optional] = starting_position.particle
#
# ...

# %%
particle = DeliveryService(nr_couriers = 2, nr_orders = 40, nr_restaurants = 3)
filename = './cases/przypadek2k40z3r.txt'
particle.save_to_file(filename)
del particle
del filename

# %% [markdown]
# ## Odtworzenie roju z pliku i eksperyment
# Wykonaj eksperymenty dla różnych parametrów {inertia,cp,cg}

# %%
from summary import *

# %%
import pandas as pd
from IPython.display import Image

# %%
experiments_logs = pd.read_csv('summary.csv')

# %%
experiments_logs['nr_couriers']
# Out:
# 0    3
# 1    3
# 2    3
# Name: nr_couriers, dtype: int64

# %%
Image(experiments_logs['changes_per_epoch_plot'][1])

# %%
Image(experiments_logs['loss_history_plot'][1])

# %%
Image(experiments_logs['best_path_plot'][1])

# %%
Image(experiments_logs['particles_history_plot'][1])

# %%
Image(experiments_logs['particles_history_plot'][0])

# %%
Image(experiments_logs['particles_history_plot'][2])

# %%
experiments_logs.plot(x='nr_particles',y='loss', kind='bar', title='Błąd w zależności od liczby osobników')

# %%
Image(experiments_logs['best_path_plot'][2])

# %%
experiments_logs.plot.bar(x='nr_particles', y='PSO_time')

# %%
experiments_logs.plot.bar(x='nr_particles', y='avg_epoch_time')

# %% [markdown]
# ## Wykonywanie eksperymentu
# 1. utwoz slownik parametrow gdzie n-ty element listy to wartosc parametru dla n-tego przypadku
# 2. wywolaj funkcje GridSearch z argumentem ('nazwa_pliku_z_przypadkiem_testowym', slownik) np:

# %%
from summary import *
run_pso_and_save_summary('przypadek3k60z3r.txt',20,0.1,0.1,0.1,40,draw_route=False)
# Out:
# /home/smaket/PycharmProjects/PSO_food_delivery
# przypadek3k60z3r20_01_01_01_40.png
# przypadek3k60z3r20_01_01_01_40.txt
# /home/smaket/PycharmProjects/PSO_food_delivery/drawing_utils.py:94: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# /home/smaket/PycharmProjects/PSO_food_delivery/drawing_utils.py:104: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# /home/smaket/PycharmProjects/PSO_food_delivery/drawing_utils.py:120: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# ...

# %%
Image('mobility_plots/przypadek3k60z3r20_01_01_01_40.png')

# %%
Image('swarm_loss_plots/przypadek3k60z3r20_01_01_01_40.png')

# %%
from summary import *
#WYWOLANIE TRZECH PRZYPADKOW
test_dict = {'nr_particles':[10,20,40],'inertia':[0.1,0.2,0.1], 'cg':[0.1,0.3,0.1], 'cp':[0.1,0.3,0.1],
             'nr_epochs':[20,40,50]}
GridSearchPSO('cases/przypadek10k200z20r.txt', test_dict)

# %%
Image('swarm_loss_plots/przypadek3k60z3r20_01_01_01_40.png')

# %%
from summary import *
#WYWOLANIE TRZECH PRZYPADKOW
test_dict = {'nr_particles':[10,20,40],'inertia':[0.1,0.2,0.1], 'cg':[0.1,0.3,0.1], 'cp':[0.1,0.3,0.1],
             'nr_epochs':[20,40,50]}
GridSearchPSO('cases/przypadek10k200z20r.txt', test_dict)

# %%
# Out:
# /home/smaket/PycharmProjects/PSO_food_delivery
# przypadek1k1000z10r10_01_01_01_20.png
# przypadek1k1000z10r10_01_01_01_20.txt
# /home/smaket/PycharmProjects/PSO_food_delivery/drawing_utils.py:89: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# /home/smaket/PycharmProjects/PSO_food_delivery/drawing_utils.py:99: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# /home/smaket/PycharmProjects/PSO_food_delivery/drawing_utils.py:115: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
from summary import *
run
#WYWOLANIE TRZECH PRZYPADKOW
# test_dict = {'nr_particles':[10,20,40],'inertia':[0.1,0.2,0.1], 'cg':[0.1,0.3,0.1], 'cp':[0.1,0.3,0.1],
#              'nr_epochs':[20,40,50]}
# GridSearchPSO('cases/przypadek10k200z20r.txt', test_dict)
# Out:
# /home/smaket/PycharmProjects/PSO_food_delivery
# przypadek10k200z20r10_01_01_01_20.png
# przypadek10k200z20r10_01_01_01_20.txt
# /home/smaket/PycharmProjects/PSO_food_delivery/drawing_utils.py:89: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# /home/smaket/PycharmProjects/PSO_food_delivery/drawing_utils.py:99: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# /home/smaket/PycharmProjects/PSO_food_delivery/drawing_utils.py:76: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# ...
