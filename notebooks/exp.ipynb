# %%
import numpy as np
import os
import matplotlib.pyplot as plt
from pso.PSO import *
from pso.delivery_swarm import *
working_path = os.pardir+'/'
# %matplotlib inline

# %% [markdown]
# ## Utworzenie przypadku i zapis do pliku
# 1. przed utworzeniem zrestartuj kernel
# 2. przy tworzeniu nowego przypadku zastosuj NazwaPrzypadku(liczba_kurierów)k(liczba_zamówień)z(liczba_restauracji)r.txt

# %%
particle = DeliveryService(nr_couriers = 2, nr_orders = 8, nr_restaurants = 4)
filename =  '2c8o4r.txt'
particle.save_to_file(filename)

# %% [markdown]
# ## Odtworzenie roju z pliku i eksperyment
# Wykonaj eksperymenty dla różnych parametrów {inertia,cp,cg}

# %%
from pso.summary import *

# %%
import warnings
import tqdm
warnings.filterwarnings('ignore')
from pso.summary import *
filename = '2c8o4r.txt'
csv_file = '../data/summary.csv'
run_pso_and_save_summary(filename,20,0.1,0.2,0.1,30,draw_route=False,database=csv_file)

# %%
import pandas as pd
from IPython.display import Image

# %%
experiments_logs = pd.read_csv(csv_file)
print(experiments_logs.columns)
# Out:
# Index(['case_name', 'PSO_time', 'avg_v_computation', 'avg_move_time',
#        'avg_epoch_time', 'avg_fitness_calculation_time', 'loss', 'nr_changes',
#        'nr_orders', 'nr_restaurants', 'nr_couriers', 'nr_particles',
#        'nr_epochs', 'inertia', 'cp', 'cg', 'particles_history_plot',
#        'loss_history_plot', 'best_path_plot', 'changes_per_epoch_plot',
#        'experiment_documentation'],
#       dtype='object')

# %%
showcase = experiments_logs
showcase
# Out:
#     case_name  PSO_time  avg_v_computation  avg_move_time  avg_epoch_time  \
# 0  2c8o4r.txt  1.063884           0.001414       0.000103        0.035351
# 1  2c8o4r.txt  1.123053           0.001454       0.000108        0.037301
# 2  2c8o4r.txt  0.918967           0.001211       0.000105        0.030524
# 3  2c8o4r.txt  1.198906           0.001558       0.000116        0.039787
# 4  2c8o4r.txt  0.991514           0.001295       0.000108        0.032919
# 5  2c8o4r.txt  0.847392           0.001111       0.000081        0.028133
# 6  2c8o4r.txt  0.940924           0.001244       0.000098        0.031240
#
#    avg_fitness_calculation_time       loss  nr_changes  nr_orders  \
# 0                      0.000108  33.609727           5          8
# 1                      0.000127  23.528393          10          8
# 2                      0.000088  23.530440           3          8
# 3                      0.000132  41.338723           5          8
# 4                      0.000103  26.249464           5          8
# 5                      0.000087  30.379444           1          8
# 6                      0.000092  23.751086           8          8
#
#    nr_restaurants  ...  nr_particles  nr_epochs  inertia   cp   cg  \
# 0               4  ...            20         30      0.1  0.2  0.3
# 1               4  ...            20         30      0.1  0.2  0.3
# 2               4  ...            20         30      0.1  0.2  0.3
# 3               4  ...            20         30      0.1  0.2  0.3
# 4               4  ...            20         30      0.1  0.2  0.3
# 5               4  ...            20         30      0.1  0.2  0.3
# 6               4  ...            20         30      0.1  0.2  0.1
#
#                       particles_history_plot  \
# 0  swarm_loss_plots/2c8o4r20_01_02_03_30.png
# 1  swarm_loss_plots/2c8o4r20_01_02_03_30.png
# 2  swarm_loss_plots/2c8o4r20_01_02_03_30.png
# 3  swarm_loss_plots/2c8o4r20_01_02_03_30.png
# 4  swarm_loss_plots/2c8o4r20_01_02_03_30.png
# 5  swarm_loss_plots/2c8o4r20_01_02_03_30.png
# 6  swarm_loss_plots/2c8o4r20_01_02_01_30.png
#
#                              loss_history_plot  \
# 0  loss_history_plots/2c8o4r20_01_02_03_30.png
# 1  loss_history_plots/2c8o4r20_01_02_03_30.png
# 2  loss_history_plots/2c8o4r20_01_02_03_30.png
# 3  loss_history_plots/2c8o4r20_01_02_03_30.png
# 4  loss_history_plots/2c8o4r20_01_02_03_30.png
# 5  loss_history_plots/2c8o4r20_01_02_03_30.png
# 6  loss_history_plots/2c8o4r20_01_02_01_30.png
#
#                              best_path_plot  \
# 0  best_path_plots/2c8o4r20_01_02_03_30.png
# 1  best_path_plots/2c8o4r20_01_02_03_30.png
# 2  best_path_plots/2c8o4r20_01_02_03_30.png
# 3  best_path_plots/2c8o4r20_01_02_03_30.png
# 4  best_path_plots/2c8o4r20_01_02_03_30.png
# 5  best_path_plots/2c8o4r20_01_02_03_30.png
# 6  best_path_plots/2c8o4r20_01_02_01_30.png
#
#                              changes_per_epoch_plot  \
# 0  changes_per_epoch_plots/2c8o4r20_01_02_03_30.png
# 1  changes_per_epoch_plots/2c8o4r20_01_02_03_30.png
# 2  changes_per_epoch_plots/2c8o4r20_01_02_03_30.png
# 3  changes_per_epoch_plots/2c8o4r20_01_02_03_30.png
# 4  changes_per_epoch_plots/2c8o4r20_01_02_03_30.png
# 5  changes_per_epoch_plots/2c8o4r20_01_02_03_30.png
# 6  changes_per_epoch_plots/2c8o4r20_01_02_01_30.png
#
#                experiment_documentation
# 0  experiments_documentation/2c8o4r.txt
# 1  experiments_documentation/2c8o4r.txt
# 2  experiments_documentation/2c8o4r.txt
# 3  experiments_documentation/2c8o4r.txt
# 4  experiments_documentation/2c8o4r.txt
# 5  experiments_documentation/2c8o4r.txt
# 6  experiments_documentation/2c8o4r.txt
#
# [7 rows x 21 columns]

# %%
from scipy.stats import zscore
fig, ax =plt.subplots()
ax.set(title = 'Rozkład funkcji kosztu dla wywołanych przypadków')
showcase.boxplot('loss',ax = ax)
showcase['z_scores'] = zscore(showcase['loss'])
filtered_entries = showcase[abs(showcase['z_scores'])<3]
fig2, ax2 =plt.subplots()
filtered_entries.loss.hist(ax = ax2, bins = 30)
ax2.set(title = 'Rozłkad po usunięciu wartości odstających', xlabel = 'koszt', ylabel = 'ilość')
ax2.axvline(showcase.loss.mean(), c = 'red')
ax2.axvline(showcase.loss.mean()-showcase.loss.std(),c = 'red')
ax2.axvline(showcase.loss.mean()+showcase.loss.std(),c = 'red')
